# %%
pip install unsloth
# Out:
# Requirement already satisfied: unsloth in /usr/local/lib/python3.11/dist-packages (2025.2.15)
# Requirement already satisfied: unsloth_zoo>=2025.2.7 in /usr/local/lib/python3.11/dist-packages (from unsloth) (2025.2.7)
# Requirement already satisfied: torch>=2.4.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (2.6.0)
# Requirement already satisfied: xformers>=0.0.27.post2 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.0.29.post3)
# Requirement already satisfied: bitsandbytes in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.45.3)
# Requirement already satisfied: triton>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (3.2.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from unsloth) (24.2)
# Requirement already satisfied: tyro in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.9.16)
# Requirement already satisfied: transformers!=4.47.0,>=4.46.1 in /usr/local/lib/python3.11/dist-packages (from unsloth) (4.48.3)
# Requirement already satisfied: datasets>=2.16.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (3.3.2)
# Requirement already satisfied: sentencepiece>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from unsloth) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from unsloth) (5.9.5)
# Requirement already satisfied: wheel>=0.42.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.45.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from unsloth) (1.26.4)
# Requirement already satisfied: accelerate>=0.34.1 in /usr/local/lib/python3.11/dist-packages (from unsloth) (1.3.0)
# Requirement already satisfied: trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.15.2)
# Requirement already satisfied: peft!=0.11.0,>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.14.0)
# Requirement already satisfied: protobuf<4.0.0 in /usr/local/lib/python3.11/dist-packages (from unsloth) (3.20.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.28.1)
# Requirement already satisfied: hf_transfer in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.32.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from unsloth) (0.21.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.1->unsloth) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate>=0.34.1->unsloth) (0.5.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (3.17.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (2.32.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets>=2.16.0->unsloth) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets>=2.16.0->unsloth) (3.11.13)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->unsloth) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (12.4.127)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.4.0->unsloth) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,>=4.46.1->unsloth) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers!=4.47.0,>=4.46.1->unsloth) (0.21.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (13.9.4)
# Requirement already satisfied: cut_cross_entropy in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.2.7->unsloth) (25.1.1)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from unsloth_zoo>=2025.2.7->unsloth) (11.1.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from diffusers->unsloth) (8.6.1)
# Requirement already satisfied: docstring-parser>=0.15 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth) (0.16)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth) (1.7.1)
# Requirement already satisfied: typeguard>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from tyro->unsloth) (4.4.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets>=2.16.0->unsloth) (1.18.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets>=2.16.0->unsloth) (2025.1.31)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (2.18.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->diffusers->unsloth) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets>=2.16.0->unsloth) (2025.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl!=0.15.0,!=0.9.0,!=0.9.1,!=0.9.2,!=0.9.3,>=0.7.9->unsloth) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets>=2.16.0->unsloth) (1.17.0)

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 2048
dtype = None
load_in_4bit = True
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Qwen2.5-Coder-0.5B-Instruct-bnb-4bit",
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = True,

)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# ==((====))==  Unsloth 2025.2.15: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!

# %%
loftq_config = {"bits": 4}
model = FastLanguageModel.get_peft_model(
    model,
    r = 32,
    target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                      "gate_proj", "up_proj", "down_proj",],
    lora_alpha = 64,
    lora_dropout = 0,
    bias = "none",
    use_gradient_checkpointing = "unsloth", # True or "unsloth" for very long context
    random_state = 3407,
    use_rslora = True,
    loftq_config = loftq_config, # And LoftQ
)
# Out:
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/config.py:455: UserWarning: `loftq_config` specified but will be ignored when `init_lora_weights` is not 'loftq'.
#   warnings.warn("`loftq_config` specified but will be ignored when `init_lora_weights` is not 'loftq'.")
# Unsloth 2025.2.15 patched 24 layers with 24 QKV layers, 24 O layers and 24 MLP layers.

# %%
import pandas as pd
import json


file_path = "/content/train_data_v4.csv"
df = pd.read_csv(file_path)


dataset = df.drop_duplicates()

dataset["mongo_query"] = dataset["mongo_query"].str.replace("'", '"')


dataset["mongo_query"] = dataset["mongo_query"].str.rstrip(";")


def is_valid_json(text):
    try:
        json.loads(text)
        return True
    except:
        return False

dataset = dataset[dataset["schema"].apply(is_valid_json)]


dataset.to_csv("train_data_v4_cleaned.csv", index=False)


print("Cleaning complete. Saved as 'train_data_v4_cleaned.csv'.")
dataset.head()
# Out:
# Cleaning complete. Saved as 'train_data_v4_cleaned.csv'.
# <ipython-input-4-bb4014fe6ea4>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["mongo_query"] = dataset["mongo_query"].str.replace("'", '"')
# <ipython-input-4-bb4014fe6ea4>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset["mongo_query"] = dataset["mongo_query"].str.rstrip(";")
#      database_id                                             schema  \
# 0  traffic_event  {\n  "collections": [{\n    "name": "traffic_e...
# 1  traffic_event  {\n  "collections": [{\n    "name": "traffic_e...
# 2  traffic_event  {\n  "collections": [{\n    "name": "traffic_e...
# 3  traffic_event  {\n  "collections": [{\n    "name": "traffic_e...
# 4  traffic_event  {\n  "collections": [{\n    "name": "traffic_e...
#
#                                          mongo_query  \
# 0                         db.traffic_events.find({})
# 1                         db.traffic_events.find({})
# 2  db.traffic_events.find({ "identifier.intersect...
# 3  db.traffic_events.find({ "identifier.intersect...
# 4  db.traffic_events.find({ "response.event.sever...
#
#                               natural_language_query
# 0  Retrieve all traffic events with details about...
# 1  Retrieve all recorded traffic events with thei...
# 2  Retrieve all traffic event records for the int...
# 3  Retrieve all traffic event records for the int...
# 4  Retrieve all traffic events with critical seve...

# %%
model_name = "unsloth/Qwen2.5-Coder-0.5B-Instruct-bnb-4bit"

# %%
import pandas as pd
from datasets import Dataset
from transformers import AutoTokenizer


file_path = "/content/train_data_v4_cleaned.csv"
df = pd.read_csv(file_path)


df.rename(columns={
    "database_id": "db_id",
    "schema": "schema_info",
    "natural_language_query": "nl_query",
    "mongo_query": "mongo_query"
}, inplace=True)


df["instruction"] = "Generate a MongoDB query from the given database schema and natural language request."
df["input"] = df.apply(lambda row: f"Database ID: {row['db_id']}\nSchema: {row['schema_info']}\nQuery: {row['nl_query']}", axis=1)
df["output"] = df["mongo_query"]


tokenizer = AutoTokenizer.from_pretrained(model_name)


alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token


def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs = examples["input"]
    outputs = examples["output"]
    texts = []

    for instruction, input_text, output in zip(instructions, inputs, outputs):
        text = alpaca_prompt.format(instruction, input_text, output) + EOS_TOKEN
        texts.append(text)

    return {"text": texts}


dataset = Dataset.from_pandas(df)


dataset = dataset.map(formatting_prompts_func, batched=True)

print(dataset[0]["text"])
# Out:
# tokenizer_config.json:   0%|          | 0.00/7.51k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/1.67M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.03M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/632 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/613 [00:00<?, ?B/s]
# Map:   0%|          | 0/1431 [00:00<?, ? examples/s]
# Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Generate a MongoDB query from the given database schema and natural language request.
#
# ### Input:
# Database ID: traffic_event
# Schema: {
#   "collections": [{
#     "name": "traffic_events",
#     "document": {
#       "properties": {
#         "identifier": {
#           "bsonType": "object",
#           "properties": {
#             "intersection_id": {"description": "Filter by traffic junction"},
#             "camera_id": {"description": "Filter by surveillance unit"}
#           }
#         },
#         "response": {
#           "bsonType": "object",
#           "properties": {
#             "event": {
#               "properties": {
#                 "severity": {"description": "Critical, High, Low"},
#                 "type": {"description": "Speeding, RedLightViolation, IllegalParking"},
#                 "vehicles": {
#                   "bsonType": "array",
#                   "items": {
#                     "properties": {
#                       "number_plate": {
#                         "bsonType": "string",
#                         "pattern": "^[A-Z]{2}[0-9]{2}[A-Z]{2}[0-9]{4}$"
#                       },
#                       "speed": {"bsonType": "double"},
#                       "timestamp": {"bsonType": "date"},
#                       "location": {
#                         "bsonType": "array",
#                         "items": {"bsonType": "double"}
#                       }
#                     }
#                   }
#                 }
#               }
#             }
#           }
#         }
#       }
#     }
#   }],
#   "version": 2
# }
#
# Query: Retrieve all traffic events with details about each incident.
#
# ### Response:
# db.traffic_events.find({})<|im_end|>

# %%
from datasets import load_dataset  # Import this!

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

sft_data = load_dataset("csv", data_files={"train": "train_data_v4.csv"})
EOS_TOKEN = tokenizer.eos_token
def preprocess_sft(example):
    input_text = f"Generate a MongoDB query for the following user input.\n UserInput: {example['natural_language_query']}\n The name of the database is {example['database_id']} having schema {example['schema']}."
    target_text = str(example["mongo_query"])
    prompt = f"### Instruction:Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.\n{input_text}\n\n### MongoDB Query:\n{target_text}\n"+EOS_TOKEN
    tokenized = tokenizer(prompt, truncation=True, padding="max_length", max_length=512)
    return tokenized

tokenized_sft = sft_data.map(preprocess_sft, batched=False)
# Out:
# Generating train split: 0 examples [00:00, ? examples/s]
# Map:   0%|          | 0/1617 [00:00<?, ? examples/s]

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, TrainingArguments
sft_training_args = TrainingArguments(
    output_dir="sft_output",
    evaluation_strategy="steps",
    eval_steps=100,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    num_train_epochs=3,
    learning_rate=5e-5,
    weight_decay=0.01,
    logging_steps=50,
    save_steps=200,
    report_to="none",
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
from trl import SFTTrainer
sft_trainer = SFTTrainer(
    model=model,
    args=sft_training_args,
    evaluation_strategy="no",
    do_eval=False,
    train_dataset=dataset,
    tokenizer=tokenizer,
)
# Out:
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# Converting train dataset to ChatML (num_proc=2):   0%|          | 0/1431 [00:00<?, ? examples/s]
# Applying chat template to train dataset (num_proc=2):   0%|          | 0/1431 [00:00<?, ? examples/s]
# Tokenizing train dataset (num_proc=2):   0%|          | 0/1431 [00:00<?, ? examples/s]
# Truncating train dataset (num_proc=2):   0%|          | 0/1431 [00:00<?, ? examples/s]

# %%
sft_trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs = 1
#    \\   /|    Num examples = 1,431 | Num Epochs = 3
# O^O/ \_/ \    Batch size per device = 8 | Gradient Accumulation steps = 1
# \        /    Total batch size = 8 | Total steps = 537
#  "-____-"     Number of trainable parameters = 17,596,416
#     <div>
#
#       <progress value='537' max='537' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [537/537 14:19, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.175400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.084500</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.073700</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.068500</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.059700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.055300</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.055100</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.046800</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.042300</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.043500</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=537, training_loss=0.06863187256250079, metrics={'train_runtime': 871.8243, 'train_samples_per_second': 4.924, 'train_steps_per_second': 0.616, 'total_flos': 8233664523599616.0, 'train_loss': 0.06863187256250079})

# %%
from peft import PeftModel
import torch

# Define the save directory
lora_save_directory = "./lora_trained_model"

# Save only LoRA adapters (not full model)
model.save_pretrained(lora_save_directory)
tokenizer.save_pretrained(lora_save_directory)

print(f"LoRA adapters saved at {lora_save_directory}")
# Out:
# LoRA adapters saved at ./lora_trained_model

# %%
import os

lora_save_directory = "./lora_trained_model"

# List saved files
print("Files in LoRA save directory:")
print(os.listdir(lora_save_directory))
# Out:
# Files in LoRA save directory:
# ['vocab.json', 'merges.txt', 'adapter_config.json', 'tokenizer.json', 'special_tokens_map.json', 'tokenizer_config.json', 'added_tokens.json', 'README.md', 'adapter_model.safetensors']

# %%
import torch
from unsloth import FastLanguageModel
from transformers import AutoTokenizer
from peft import PeftModel

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Define paths
base_model_name = "unsloth/Qwen2.5-Coder-0.5B-Instruct-bnb-4bit"  # Base model
lora_model_path = "./lora_trained_model"  # LoRA adapters (your saved directory)

# Load tokenizer from LoRA adapter directory
tokenizer = AutoTokenizer.from_pretrained(lora_model_path)

# Load base model
model, _ = FastLanguageModel.from_pretrained(base_model_name, load_in_4bit=True)
model.to(device)

# Load LoRA adapters
model = PeftModel.from_pretrained(model, lora_model_path)

# Optimize for inference
FastLanguageModel.for_inference(model)

print("✅ LoRA fine-tuned model loaded successfully!")
# Out:
# ==((====))==  Unsloth 2025.2.15: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ✅ LoRA fine-tuned model loaded successfully!

# %%
for name, param in model.named_parameters():
    if "lora" in name.lower():
        print(f"LoRA Parameter Found: {name} | Trainable: {param.requires_grad}")
# Out:
# LoRA Parameter Found: base_model.model.model.layers.0.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.0.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.1.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.2.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.3.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.4.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.5.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.6.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.7.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.8.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.9.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.10.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.11.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.12.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.13.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.14.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.15.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.16.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.17.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.18.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.19.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.20.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.21.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.22.mlp.down_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.self_attn.q_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.self_attn.q_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.self_attn.k_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.self_attn.k_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.self_attn.v_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.self_attn.v_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.self_attn.o_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.self_attn.o_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.mlp.gate_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.mlp.gate_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.mlp.up_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.mlp.up_proj.lora_B.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.mlp.down_proj.lora_A.default.weight | Trainable: False
# LoRA Parameter Found: base_model.model.model.layers.23.mlp.down_proj.lora_B.default.weight | Trainable: False

# %%
from peft import get_peft_model_state_dict

lora_state_dict = get_peft_model_state_dict(model)
if len(lora_state_dict) > 0:
    print("✅ LoRA adapters are correctly loaded!")
else:
    print("❌ LoRA adapters are NOT loaded correctly. Check the save path.")
# Out:
# ✅ LoRA adapters are correctly loaded!

# %%
def generate_mongo_query(nl_query, db_id, schema_info):
    model.eval()  # Set to inference mode

    prompt = f"""Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
Generate a MongoDB query from the given database schema and natural language request.

### Input:
Database ID: {db_id}
Schema: {schema_info}
Query: {nl_query}

### Response:
"""

    # Tokenize input
    inputs = tokenizer(prompt, return_tensors="pt").to(device)

    # Generate output
    with torch.no_grad():
        output_ids = model.generate(**inputs, max_length=512)

    # Decode output
    generated_text = tokenizer.decode(output_ids[0], skip_special_tokens=True)

    return generated_text

# Example Test
nl_query = "List all traffic events with critical severity."
db_id = "traffic_event"
schema_info = '"{ ""collections"": [{ ""name"": ""traffic_events"", ""document"": { ""properties"": { ""identifier"": { ""bsonType"": ""object"", ""properties"": { ""intersection_id"": {""description"": ""Filter by traffic junction""}, ""camera_id"": {""description"": ""Filter by surveillance unit""} } }, ""response"": { ""bsonType"": ""object"", ""properties"": { ""event"": { ""properties"": { ""severity"": {""description"": ""Critical, High, Low""}, ""type"": {""description"": ""Speeding, RedLightViolation, IllegalParking""}, ""vehicles"": { ""bsonType"": ""array"", ""items"": { ""properties"": { ""number_plate"": { ""bsonType"": ""string"", ""pattern"": ""^[A-Z]{2}[0-9]{2}[A-Z]{2}[0-9]{4}$"" }, ""speed"": {""bsonType"": ""double""}, ""timestamp"": {""bsonType"": ""date""}, ""location"": { ""bsonType"": ""array"", ""items"": {""bsonType"": ""double""} } } } } } } } } } } }], ""version"": 2 } "'

print("Generated MongoDB Query:\n", generate_mongo_query(nl_query, db_id, schema_info))
# Out:
# Generated MongoDB Query:
#  Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Generate a MongoDB query from the given database schema and natural language request.
#
# ### Input:
# Database ID: traffic_event
# Schema: "{ ""collections"": [{ ""name"": ""traffic_events"", ""document"": { ""properties"": { ""identifier"": { ""bsonType"": ""object"", ""properties"": { ""intersection_id"": {""description"": ""Filter by traffic junction""}, ""camera_id"": {""description"": ""Filter by surveillance unit""} } }, ""response"": { ""bsonType"": ""object"", ""properties"": { ""event"": { ""properties"": { ""severity"": {""description"": ""Critical, High, Low""}, ""type"": {""description"": ""Speeding, RedLightViolation, IllegalParking""}, ""vehicles"": { ""bsonType"": ""array"", ""items"": { ""properties"": { ""number_plate"": { ""bsonType"": ""string"", ""pattern"": ""^[A-Z]{2}[0-9]{2}[A-Z]{2}[0-9]{4}$"" }, ""speed"": {""bsonType"": ""double""}, ""timestamp"": {""bsonType"": ""date""}, ""location"": { ""bsonType"": ""array"", ""items"": {""bsonType"": ""double""} } } } } } } } } } } }], ""version"": 2 } "
# Query: List all traffic events with critical severity.
#
# ### Response:
# db.traffic_events.find({ "response.event.severity": "Critical" })

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import shutil
import os
from peft import PeftModel
from unsloth import FastLanguageModel
from transformers import AutoTokenizer

# Define paths
base_model_name = "unsloth/Qwen2.5-Coder-0.5B-Instruct-bnb-4bit"  # Base model
lora_model_path = "./lora_trained_model"  # LoRA adapter path
save_path = "/content/drive/MyDrive/merged_model"  # Save location in Google Drive

# Load base model
model, tokenizer = FastLanguageModel.from_pretrained(base_model_name)

# Load LoRA adapters and merge
model = PeftModel.from_pretrained(model, lora_model_path)
model = model.merge_and_unload()  # Merge LoRA with base model

# Save the merged model
model.save_pretrained(save_path)
tokenizer.save_pretrained(save_path)

print(f"✅ Merged model saved at {save_path}")
# Out:
# ==((====))==  Unsloth 2025.2.15: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/bnb.py:355: UserWarning: Merge lora module to 4-bit linear may get different generations due to rounding errors.
#   warnings.warn(
# ✅ Merged model saved at /content/drive/MyDrive/merged_model

# %%
import os
print(os.listdir("/content/drive/MyDrive/merged_model"))
# Out:
# ['config.json', 'generation_config.json', 'model.safetensors', 'tokenizer_config.json', 'special_tokens_map.json', 'added_tokens.json', 'vocab.json', 'merges.txt', 'tokenizer.json']

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Define paths
merged_model_path = "/content/drive/MyDrive/merged_model_fp16"  # Path to merged model
model_file = f"{merged_model_path}/adapter_model.safetensors"  # Model file

# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load tokenizer (Use merged model tokenizer)
tokenizer = AutoTokenizer.from_pretrained(merged_model_path)

# Load merged model directly (since LoRA is already merged)
model = AutoModelForCausalLM.from_pretrained(
    merged_model_path,
    torch_dtype=torch.float16,  # Ensure correct precision
    device_map="auto"  # Automatically use GPU if available
)

print("✅ Merged model loaded successfully from Google Drive!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Merged model loaded successfully from Google Drive!

# %%
# Define the prompt format
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
"""

def generate_response(db_id, schema_info, nl_query, max_new_tokens=150):
    # Format input similar to training format
    formatted_input = alpaca_prompt.format(
        "Generate a MongoDB query from the given database schema and natural language request.",
        f"Database ID: {db_id}\nSchema: {schema_info}\nQuery: {nl_query}"
    )

    # Tokenize input and move to device
    inputs = tokenizer(formatted_input, return_tensors="pt").to(device)

    # Generate response
    with torch.no_grad():
        output = model.generate(**inputs, max_new_tokens=max_new_tokens)

    # Decode output
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

    # Extract response after "### Response:"
    return generated_text.split("### Response:")[-1].strip()

# Example Test
db_id = "example_db"
schema_info = "{ users: { name: String, age: Number }, orders: { total: Number, user_id: String } }"
nl_query = "Find all users older than 30."

mongo_query = generate_response(db_id, schema_info, nl_query)

print("\n🔹 Generated MongoDB Query:\n", mongo_query)
# Out:
# 🔹 Generated MongoDB Query:
#  To generate a MongoDB query from the given database schema and natural language request, you can use the following query:
#
# ```javascript
# db.example_db.users.find({ age: { $gt: 30 } });
# ```
#
# This query selects all users from the `users` collection where their age is greater than 30. Make sure to replace `example_db` with the actual name of your database.

# %%
import torch
from unsloth import FastLanguageModel
from transformers import AutoTokenizer
from google.colab import drive

# ✅ Mount Google Drive
drive.mount('/content/drive')

# ✅ Define paths
merged_model_path = "/content/drive/MyDrive/merged_model_fp16"  # Path to merged model

# ✅ Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# ✅ Load tokenizer from merged model directory
tokenizer = AutoTokenizer.from_pretrained(merged_model_path)

# ✅ Load the merged fine-tuned model (NO LoRA loading needed)
model, _ = FastLanguageModel.from_pretrained(
    merged_model_path,  # The already fine-tuned model
    load_in_4bit=True  # Efficient 4-bit precision loading
)
model.to(device)

# ✅ Optimize for inference
FastLanguageModel.for_inference(model)

print("✅ Merged fine-tuned model loaded successfully!")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ==((====))==  Unsloth 2025.2.15: Fast Qwen2 patching. Transformers: 4.48.3.
#    \\   /|    GPU: Tesla T4. Max memory: 14.741 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 7.5. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# ✅ Merged fine-tuned model loaded successfully!
